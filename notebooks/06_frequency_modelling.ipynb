# %% [markdown]
# # Frequency modelling
#
# Run from the project environment after the documented build steps.

# %%
from src.fremtpl2.frequency import train_frequency_model
